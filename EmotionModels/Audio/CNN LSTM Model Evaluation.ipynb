# %%
import os
from Evaluation import Evaluation
from DataModel import DataModel

import warnings
warnings.filterwarnings('ignore')

# %%
logFolder = os.path.join(os.getcwd(), 'IEMOCAP_ModelLog')
resultFolder = os.path.join(os.getcwd(), 'IEMOCAP_TrainedModel')

# %% [markdown]
# # Data Model

# %%
labelsToInclude = ['Neutral', 'Frustration', 'Anger', 'Sadness', 'Happiness']
mergeHappinessExcitement = True
splitDuration = 4
ignoreDuration = 2

mixDataModel5LabelsSplit4Ignore2 = DataModel(labelsToInclude=labelsToInclude,
                                                  mergeHappinessExcitement=mergeHappinessExcitement,
                                                  splitDuration=splitDuration,
                                                  ignoreDuration=ignoreDuration)
mixDataModel5LabelsSplit4Ignore2.extractIEMOCAPData()
mixDataModel5LabelsSplit4Ignore2.extractEmoDBData()
mixDataModel5LabelsSplit4Ignore2.processTestingDataOnly()

# %% [markdown]
# # CNN LSTM Experiments

# %% [markdown]
# ## Experiment 14 (CNN LSTM Model A, 200 Epochs, IEMOCAP & EmoDB, No Aug, 5 Emotions with Merge and Split 4 Ignore 2 Batch 32)

# %%
# NOTE: "12-26 01h05m01s (Experiment 14) CNN LSTM Model F (200 Epochs) (IEMOCAP EmoDB) (No Data Aug) (5 Emotions with Merge and Split 4 Ignore 2) (0001 lr 001 decay 32 batchsize)" in GPU Farm

def experiment14(data, experimentName, trainName, validName):
  resultDir = os.path.join(resultFolder, experimentName)
  logDir = os.path.join(logFolder, experimentName)
  evaluation = Evaluation(data, resultDir, logDir)
  evaluation.evaluateAll(trainName, validName)

experimentName = '12-26 01h05m01s (Experiment 14) CNN LSTM Model A (200 Epochs) (IEMOCAP EmoDB) (No Data Aug) (5 Emotions with Merge and Split 4 Ignore 2) (0001 lr 001 decay 32 batchsize)'
trainName = 'events.out.tfevents.1671987906.gpu-comp-201.8530.0.v2'
validName = 'events.out.tfevents.1671987942.gpu-comp-201.8530.1.v2'
experiment14(mixDataModel5LabelsSplit4Ignore2, experimentName, trainName, validName)
# Out:
# Load model from /Users/alexto/Documents/Programming/HKU/FYP/Speech Emotion Recognition/IEMOCAP_TrainedModel/12-26 01h05m01s (Experiment 14) CNN LSTM Model A (200 Epochs) (IEMOCAP EmoDB) (No Data Aug) (5 Emotions with Merge and Split 4 Ignore 2) (0001 lr 001 decay 32 batchsize)
# 2022-12-27 13:30:00.530162: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Start prediction...
#
# Prediction Completed
#     Number of results: 1947
# ---------------------------------------------------------------------------
#
# ValueError                                Traceback (most recent call last)
#
# /Users/alexto/Documents/Programming/HKU/FYP/Speech Emotion Recognition/IEMOCAP CNN Model Evaluation.ipynb Cell 40 in <cell line: 10>()
# ...

# %% [markdown]
# ## Experiment 15 (CNN LSTM Model B, 200 Epochs, IEMOCAP & EmoDB, No Aug, 5 Emotions with Merge and Split 4 Ignore 2 Batch 32)

# %%
# NOTE: "12-26 02h31m05s (Experiment 15) CNN LSTM Model G (200 Epochs) (IEMOCAP EmoDB) (No Data Aug) (5 Emotions with Merge and Split 4 Ignore 2) (0001 lr 001 decay 32 batchsize)" in GPUFarm

def experiment15(data, experimentName, trainName, validName):
  resultDir = os.path.join(resultFolder, experimentName)
  logDir = os.path.join(logFolder, experimentName)
  evaluation = Evaluation(data, resultDir, logDir)
  evaluation.evaluateAll(trainName, validName)

experimentName = '12-26 02h31m05s (Experiment 15) CNN LSTM Model B (200 Epochs) (IEMOCAP EmoDB) (No Data Aug) (5 Emotions with Merge and Split 4 Ignore 2) (0001 lr 001 decay 32 batchsize)'
trainName = 'events.out.tfevents.1671993070.gpu-comp-201.12407.0.v2'
validName = 'events.out.tfevents.1671993126.gpu-comp-201.12407.1.v2'
experiment15(mixDataModel5LabelsSplit4Ignore2, experimentName, trainName, validName)
# Out:
# Load model from /Users/alexto/Documents/Programming/HKU/FYP/Speech Emotion Recognition/IEMOCAP_TrainedModel/12-26 02h31m05s (Experiment 15) CNN LSTM Model B (200 Epochs) (IEMOCAP EmoDB) (No Data Aug) (5 Emotions with Merge and Split 4 Ignore 2) (0001 lr 001 decay 32 batchsize)
#
# Start prediction...
#
# Prediction Completed
#     Number of results: 1947
#               precision    recall  f1-score   support
#
#            0       0.79      0.83      0.81       285
#            1       0.75      0.76      0.75       448
#            2       0.78      0.76      0.77       421
#            3       0.78      0.77      0.77       420
#            4       0.87      0.87      0.87       373
#
#     accuracy                           0.79      1947
#    macro avg       0.79      0.80      0.79      1947
# weighted avg       0.79      0.79      0.79      1947

# %% [markdown]
# ## Experiment 16 (CNN LSTM Model C, 200 Epochs, IEMOCAP & EmoDB, No Aug, 5 Emotions with Merge and Split 4 Ignore 2 Batch 32)

# %%
# NOTE: "12-26 03h51m28s (Experiment 16) CNN LSTM Model H (200 Epochs) (IEMOCAP EmoDB) (No Data Aug) (5 Emotions with Merge and Split 4 Ignore 2) (0001 lr 001 decay 32 batchsize)" in GPUFarm

def experiment16(data, experimentName, trainName, validName):
  resultDir = os.path.join(resultFolder, experimentName)
  logDir = os.path.join(logFolder, experimentName)
  evaluation = Evaluation(data, resultDir, logDir)
  evaluation.evaluateAll(trainName, validName)

experimentName = '12-26 03h51m28s (Experiment 16) CNN LSTM Model C (200 Epochs) (IEMOCAP EmoDB) (No Data Aug) (5 Emotions with Merge and Split 4 Ignore 2) (0001 lr 001 decay 32 batchsize)'
trainName = 'events.out.tfevents.1671997902.gpu-comp-201.16624.0.v2'
validName = 'events.out.tfevents.1671997997.gpu-comp-201.16624.1.v2'
experiment16(mixDataModel5LabelsSplit4Ignore2, experimentName, trainName, validName)
# Out:
# Load model from /Users/alexto/Documents/Programming/HKU/FYP/Speech Emotion Recognition/IEMOCAP_TrainedModel/12-26 03h51m28s (Experiment 16) CNN LSTM Model C (200 Epochs) (IEMOCAP EmoDB) (No Data Aug) (5 Emotions with Merge and Split 4 Ignore 2) (0001 lr 001 decay 32 batchsize)
#
# Start prediction...
#
# Prediction Completed
#     Number of results: 1947
#               precision    recall  f1-score   support
#
#            0       0.80      0.84      0.82       285
#            1       0.76      0.78      0.77       448
#            2       0.77      0.77      0.77       421
#            3       0.78      0.75      0.77       420
#            4       0.86      0.84      0.85       373
#
#     accuracy                           0.79      1947
#    macro avg       0.79      0.80      0.79      1947
# weighted avg       0.79      0.79      0.79      1947
